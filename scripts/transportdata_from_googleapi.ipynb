# %%
import requests
import json
from google.colab import userdata

# Function to get directions data from Google Maps Directions API
def get_directions(api_key, origin, destination, mode):
    url = f"https://maps.googleapis.com/maps/api/directions/json?origin={origin}&destination={destination}&mode={mode}&key={api_key}"
    response = requests.get(url)
    return response.json() if response.status_code == 200 else None

# Securely get your API key (make sure to add it to Colab's secrets)
api_key = userdata.get('GOOGLE_MAPS_API_KEY')

# Input locations
origin = "4045 Mason Rd, Seattle, WA 98105"
destination = "15112 NE 24th St, Redmond, WA 98052"

# Modes of transportation
modes = ["driving", "transit", "bicycling", "walking"]

# Collect data for each mode
results = {}
for mode in modes:
    data = get_directions(api_key, origin, destination, mode)
    if data and data.get("routes") and data["routes"][0].get("legs"):
        leg = data["routes"][0]["legs"][0]
        results[mode] = {
            "distance": leg["distance"]["text"],
            "duration": leg["duration"]["text"],
            "fare": data["routes"][0].get("fare", {}).get("text", "N/A")
        }
        if mode == "transit":
            steps = [step for step in leg["steps"] if step["travel_mode"] == "TRANSIT"]
            if steps:
                results[mode]["transit_details"] = [
                    {
                        "type": step["transit_details"]["line"]["vehicle"]["type"],
                        "name": step["transit_details"]["line"]["name"],
                        "departure_stop": step["transit_details"]["departure_stop"]["name"],
                        "arrival_stop": step["transit_details"]["arrival_stop"]["name"]
                    } for step in steps
                ]
    else:
        results[mode] = "No data available"

# Print results
print(json.dumps(results, indent=2))
# Out:
# {
#   "driving": {
#     "distance": "10.2 mi",
#     "duration": "16 mins",
#     "fare": "N/A"
#   },
#   "transit": {
#     "distance": "11.6 mi",
#     "duration": "58 mins",
#     "fare": "N/A",
#     "transit_details": [
#       {
#         "type": "BUS",
#         "name": "Totem Lake TC-Kirkand TC-UW Link Sta-Univ Dist",
#         "departure_stop": "Montlake Blvd NE & NE Pacific Pl - Bay 3",
#         "arrival_stop": "South Kirkland Park & Ride"
#       },
#       {
#         "type": "BUS",
#         "name": "Overlake - South Bellevue Station",
#         "departure_stop": "South Kirkland Park & Ride",
#         "arrival_stop": "Overlake Park & Ride"
#       }
#     ]
#   },
#   "bicycling": {
#     "distance": "10.0 mi",
#     "duration": "1 hour 0 mins",
#     "fare": "N/A"
#   },
#   "walking": {
#     "distance": "9.2 mi",
#     "duration": "3 hours 29 mins",
#     "fare": "N/A"
#   }
# }

# %%
import requests
import json

# Replace these with your actual values
LATITUDE = "47.654707"
LONGITUDE = "-122.303061"
API_KEY = userdata.get('GOOGLE_MAPS_API_KEY')

# Construct the URL
url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={LATITUDE},{LONGITUDE}&radius=500&types=parking&sensor=false&key={API_KEY}"

# Make the request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON response
    data = response.json()

    # Print the results
    print(json.dumps(data, indent=2))
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# {
#   "html_attributions": [],
#   "results": [
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 47.6537242,
#           "lng": -122.3025513
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 47.65507483029151,
#             "lng": -122.3012146697085
#           },
#           "southwest": {
#             "lat": 47.65237686970851,
#             "lng": -122.3039126302915
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/parking-71.png",
#       "icon_background_color": "#7B9EB0",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/parking_pinlet",
#       "name": "University of Washington IMA Parking Lot",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 3024,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/116780072772348649896\">Shaun Kuo</a>"
#           ],
#           "photo_reference": "AVzFdbl-qKFQmqEXrBE46-m0WwXltcBTY4pBlOwubDQuom1Qa_4pJAHz8-OXHpOJkkN1T9UHeZ9b1QU3TxmVezpQuYHc2kPPCuTPLVR3XwFEco1HAXU78PMugTlUaxuVE0BpHW9ZxtiXCbX9PMzpyF5WYw-QEmwLTdYTzJaJm64vtBWq1ro1",
#           "width": 4032
#         }
#       ],
#       "place_id": "ChIJqZtR45IUkFQRK9ndeqqfga4",
#       "plus_code": {
#         "compound_code": "MM3W+FX Seattle, WA, USA",
#         "global_code": "84VVMM3W+FX"
#       },
#       "rating": 4.4,
#       "reference": "ChIJqZtR45IUkFQRK9ndeqqfga4",
#       "scope": "GOOGLE",
#       "types": [
#         "parking",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 11,
#       "vicinity": "3924 Montlake Boulevard Northeast, Seattle"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 47.65620299999999,
#           "lng": -122.3012424
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 47.6575185302915,
#             "lng": -122.2999032197085
#           },
#           "southwest": {
#             "lat": 47.6548205697085,
#             "lng": -122.3026011802915
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/parking-71.png",
#       "icon_background_color": "#7B9EB0",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/parking_pinlet",
#       "name": "University of Washington Parking Lot E-18",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 3072,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/109780162831156078278\">DW Sommerville</a>"
#           ],
#           "photo_reference": "AVzFdbkoNzT6TkA0W63_4r7CvqKNgInuAveCO_2z1VSNeAD2_saaV2ybgZc5mhf3mrBgFL4pDAu-vY0uUH9NZ9RBR13uQi6EJ_GI6MXal8yvwZLgHApV6HsEl8IR5ChtaZ_JSwvTZnKHDYWJ3YLJW-8f2B6vubwubv21-aomnGgwsFIqCZmo",
#           "width": 4096
#         }
#       ],
#       "place_id": "ChIJ11LRDpIUkFQREFWCeIXNAdM",
#       "plus_code": {
#         "compound_code": "MM4X+FG Seattle, WA, USA",
#         "global_code": "84VVMM4X+FG"
#       },
#       "rating": 4.2,
#       "reference": "ChIJ11LRDpIUkFQREFWCeIXNAdM",
#       "scope": "GOOGLE",
#       "types": [
#         "parking",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 64,
#       "vicinity": "Montlake Boulevard Northeast, Seattle"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 47.6535435,
#           "lng": -122.299794
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 47.6548983302915,
#             "lng": -122.2984892197085
#           },
#           "southwest": {
#             "lat": 47.6522003697085,
#             "lng": -122.3011871802915
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/parking-71.png",
#       "icon_background_color": "#7B9EB0",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/parking_pinlet",
#       "name": "University of Washington Parking Lot E-8",
#       "opening_hours": {
#         "open_now": false
#       },
#       "place_id": "ChIJnYC7upMUkFQRFje2zda7B94",
#       "plus_code": {
#         "compound_code": "MP32+C3 Seattle, WA, USA",
#         "global_code": "84VVMP32+C3"
#       },
#       "rating": 5,
#       "reference": "ChIJnYC7upMUkFQRFje2zda7B94",
#       "scope": "GOOGLE",
#       "types": [
#         "parking",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 1,
#       "vicinity": "Walla Walla Road, Seattle"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 47.65199690000001,
#           "lng": -122.3006845
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 47.6536199802915,
#             "lng": -122.2992384197085
#           },
#           "southwest": {
#             "lat": 47.6509220197085,
#             "lng": -122.3019363802915
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/parking-71.png",
#       "icon_background_color": "#7B9EB0",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/parking_pinlet",
#       "name": "University of Washington Parking Lot",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 4032,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/112245453698201739922\">Prashant KC</a>"
#           ],
#           "photo_reference": "AVzFdbmDli8hFPZCUYg9PqQpAyfx3uiEtQlEop6m9ITHyCOMrNGjP5mmyW1MtxIlVpfPuiRLzz42lF7-xFg2-B9C5zhCr8jEUci-x2LrZ9iLiYOtY6iM7Mfg5TmRb0TojlFnXPbuPdPSthdXKkRwY1WGRGvv_q-l-nAbcNzreyRkpOIi5kn4",
#           "width": 3024
#         }
#       ],
#       "place_id": "ChIJ5SZwb5MUkFQR_wZsNGYcsFo",
#       "plus_code": {
#         "compound_code": "MM2X+QP Seattle, WA, USA",
#         "global_code": "84VVMM2X+QP"
#       },
#       "rating": 4.7,
#       "reference": "ChIJ5SZwb5MUkFQR_wZsNGYcsFo",
#       "scope": "GOOGLE",
#       "types": [
#         "parking",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 6,
#       "vicinity": "Snohomish Lane North, Seattle"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 47.65128499999999,
#           "lng": -122.3033949
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 47.65253938029149,
#             "lng": -122.3020960197085
#           },
#           "southwest": {
#             "lat": 47.64984141970849,
#             "lng": -122.3047939802915
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/parking-71.png",
#       "icon_background_color": "#7B9EB0",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/parking_pinlet",
#       "name": "Parking Lot E-17 ADA",
#       "opening_hours": {
#         "open_now": false
#       },
#       "photos": [
#         {
#           "height": 4032,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/118070499090755859882\">Nancy Singh</a>"
#           ],
#           "photo_reference": "AVzFdblbjhjJ6ziZnCkT55HPaoJnfuXEDwVY4aHKdLyrHVLJIG96VFirjPFTLEIpgbTxfIdlwK17P6wAdH8d-AQCF7RVuirdU8jI6M10vriCxbaQPTZcM6IQFiSpQs3x18L1WsfzWf4nMEd8yC4ob0rCQMNLWcHKB6h9h6wARgcvbhnd4ZV0",
#           "width": 3024
#         }
#       ],
#       "place_id": "ChIJ01k0suwUkFQRcPH2SWuS3iM",
#       "plus_code": {
#         "compound_code": "MM2W+GJ Seattle, WA, USA",
#         "global_code": "84VVMM2W+GJ"
#       },
#       "rating": 4.1,
#       "reference": "ChIJ01k0suwUkFQRcPH2SWuS3iM",
#       "scope": "GOOGLE",
#       "types": [
#         "parking",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 11,
#       "vicinity": "Northeast Pacific Place, Seattle"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 47.65676059999999,
#           "lng": -122.3029475
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 47.6582228802915,
#             "lng": -122.3014465697085
#           },
#           "southwest": {
#             "lat": 47.6555249197085,
#             "lng": -122.3041445302915
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/parking-71.png",
#       "icon_background_color": "#7B9EB0",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/parking_pinlet",
#       "name": "N21",
#       "place_id": "ChIJT62iko0UkFQRQzSxJpWIF_k",
#       "plus_code": {
#         "compound_code": "MM4W+PR Seattle, WA, USA",
#         "global_code": "84VVMM4W+PR"
#       },
#       "rating": 5,
#       "reference": "ChIJT62iko0UkFQRQzSxJpWIF_k",
#       "scope": "GOOGLE",
#       "types": [
#         "parking",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 1,
#       "vicinity": "4000 Mason Road, Seattle"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 47.65713110000001,
#           "lng": -122.3031491
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 47.6587907802915,
#             "lng": -122.3016078197085
#           },
#           "southwest": {
#             "lat": 47.6560928197085,
#             "lng": -122.3043057802915
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/parking-71.png",
#       "icon_background_color": "#7B9EB0",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/parking_pinlet",
#       "name": "Padelford Parking Garage",
#       "photos": [
#         {
#           "height": 3024,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/114116538679615944901\">Connor J</a>"
#           ],
#           "photo_reference": "AVzFdbmZFLCMEIGAgCwnBlFSy4PNP4lIaVJaaHQHFgopKia1hUe4l7W-eMZ1WXU7OvkLqJm9p0O8G9kFhQeJvmVFaTRRU_OQd_SjOTOQBx12pQpQhGuN7w24sRH7o_WW-2AIVZZGK-pSSlfPOZMUc0_cipq0vGs3vjskBIG_8JwqAz-0AI3h",
#           "width": 4032
#         }
#       ],
#       "place_id": "ChIJqxYplY0UkFQRM40ldKW0iDw",
#       "plus_code": {
#         "compound_code": "MM4W+VP Seattle, WA, USA",
#         "global_code": "84VVMM4W+VP"
#       },
#       "rating": 3.6,
#       "reference": "ChIJqxYplY0UkFQRM40ldKW0iDw",
#       "scope": "GOOGLE",
#       "types": [
#         "parking",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 43,
#       "vicinity": "Seattle"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 47.6511351,
#           "lng": -122.3028554
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 47.6525394302915,
#             "lng": -122.3016037697085
#           },
#           "southwest": {
#             "lat": 47.6498414697085,
#             "lng": -122.3043017302915
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/parking-71.png",
#       "icon_background_color": "#7B9EB0",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/parking_pinlet",
#       "name": "E90",
#       "photos": [
#         {
#           "height": 3024,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/113058626349653013159\">Scott Kubiszewski</a>"
#           ],
#           "photo_reference": "AVzFdbkO3TwWC7J0-5401xYefyqhi8Ouu-qR-RVqEMU-v2Ss00yQNkfHdzzO9lupl6J9P9vAhuD5Vy9FlZdvu5aCYovlL-aErjed2mYmFvbtxsr3rN2qseX2Y_3q79WWMqZBSVRlMU1_1O2b-qd2oZiCNbogPkAlhA4f4twUU78EcvespYNW",
#           "width": 4032
#         }
#       ],
#       "place_id": "ChIJVVUlrewUkFQRvHvqhL6FuRs",
#       "plus_code": {
#         "compound_code": "MM2W+FV Seattle, WA, USA",
#         "global_code": "84VVMM2W+FV"
#       },
#       "reference": "ChIJVVUlrewUkFQRvHvqhL6FuRs",
#       "scope": "GOOGLE",
#       "types": [
#         "parking",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Seattle"
#     },
#     {
#       "business_status": "OPERATIONAL",
#       "geometry": {
#         "location": {
#           "lat": 47.6586503,
#           "lng": -122.3046454
#         },
#         "viewport": {
#           "northeast": {
#             "lat": 47.6601342302915,
#             "lng": -122.3031418697085
#           },
#           "southwest": {
#             "lat": 47.6574362697085,
#             "lng": -122.3058398302915
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/parking-71.png",
#       "icon_background_color": "#7B9EB0",
#       "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/parking_pinlet",
#       "name": "N06",
#       "place_id": "ChIJWxy0NowUkFQRzq5P5rPTvuI",
#       "plus_code": {
#         "compound_code": "MM5W+F4 Seattle, WA, USA",
#         "global_code": "84VVMM5W+F4"
#       },
#       "reference": "ChIJWxy0NowUkFQRzq5P5rPTvuI",
#       "scope": "GOOGLE",
#       "types": [
#         "parking",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "4249 Little Canoe Channel Northeast, Seattle"
#     }
#   ],
#   "status": "OK"
# }
